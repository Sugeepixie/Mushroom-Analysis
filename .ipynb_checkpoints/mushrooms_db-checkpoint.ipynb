# %%
import pandas as pd
import sqlite3

# %%
con = sqlite3.connect("mushrooms.db")
cur = con.cursor()

# %%
# Import mushroom data as data frame

mushrooms_encoded_df = pd.read_csv('Mushrooms_encoded.csv')

# mushrooms_encoded_df.head()

mushrooms_encoded_df = mushrooms_encoded_df.drop(columns="Unnamed: 0")
mushrooms_encoded_df.head()
# Out:
#    class  cap_shape  cap_surface  cap_color  bruises  odor  gill_attachment  \
# 0      1          5            2          4        1     6                1
# 1      0          5            2          9        1     0                1
# 2      0          0            2          8        1     3                1
# 3      1          5            3          8        1     6                1
# 4      0          5            2          3        0     5                1
#
#    gill_spacing  gill_size  gill_color  ...  stalk_surface_below_ring  \
# 0             0          1           4  ...                         2
# 1             0          0           4  ...                         2
# 2             0          0           5  ...                         2
# 3             0          1           5  ...                         2
# 4             1          0           4  ...                         2
#
#    stalk_color_above_ring  stalk_color_below_ring  veil_type  veil_color  \
# ...

# %%
cur.execute("create table features (cap_shape integer, cap_surface integer, cap_color integer, bruises integer, odor integer, gill_attachment integer, gill_spacing integer, gill_size integer, gill_color integer, stalk_shape integer, stalk_root integer, stalk_surface_above_ring integer, stalk_surface_below_ring integer, stalk_color_above_ring integer, stalk_color_below_ring integer, veil_type integer, veil_color integer, ring_number integer, ring_type integer, spore_print_color integer, population integer, habitat integer)")

# %%
con.commit()
